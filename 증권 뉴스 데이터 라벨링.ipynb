# %% [markdown]
# ## 시황 전망

# %%
import requests
from bs4 import BeautifulSoup
from datetime import datetime, timedelta

# 뉴스 데이터를 저장할 리스트
market_conditions = []

# 날짜와 페이지 번호 반복
for day in range(30, 0, -1):  # 20240705부터 20240701까지
    date = f'202406{day:02d}'
    for page in range(1, 20):  # 각 날짜의 페이지 번호 1부터 4까지
        # 현재 페이지 URL 생성
        url = f'https://finance.naver.com/news/news_list.naver?mode=LSS3D&section_id=101&section_id2=258&section_id3=401&date={date}&page={page}'

        # 웹사이트에 HTTP GET 요청을 보내서 페이지 내용을 가져옴
        response = requests.get(url)

        # BeautifulSoup을 사용하여 페이지 파싱
        soup = BeautifulSoup(response.content, 'html.parser')

        # 상단 10개의 기사 추출
        top_articles = soup.select('li.newsList.top dl dd.articleSubject a')
        for title_tag in top_articles:
            title = title_tag.text.strip() if title_tag else "No title"
            news_item = {
                'title': title,
                'label': str(0)
            }
            market_conditions.append(news_item)

        # 하단 10개의 기사 추출
        bottom_articles = soup.select('li.newsList:not(.top) dl dd.articleSubject a')
        for title_tag in bottom_articles:
            title = title_tag.text.strip() if title_tag else "No title"
            news_item = {
                'title': title,
                'label': str(0)
            }
            market_conditions.append(news_item)

# 수집한 뉴스 데이터를 출력
for news in market_conditions:
    print(f"Title: {news['title']}")
    print(f"Label: {news['label']}")
# Out:
# 스트리밍 출력 내용이 길어서 마지막 5000줄이 삭제되었습니다.
# Title: ‘TIMEFOLIO 글로벌안티에이징바이오액티브’ ETF, 2일 상장
# Label: 0
# Title: 다올證, AI 플랫폼으로 임직원 사칭 범죄 선제 탐지
# Label: 0
# Title: 코스피, 장중 상승 전환하며 2780선 회복…SK하이닉스 4%↑
# Label: 0
# Title: 위메이드 계열사, ‘위믹스’ 토크노믹스 개편에 동반 강세
# Label: 0
# Title: 대원전선, 美 수주 기대감에 20% 급등[특징주]
# Label: 0
# Title: 다올금융그룹, AI 기술로 임직원 사칭 투자사기 대응
# Label: 0
# Title: 코스피, 개인·외국인 매수 '쌍끌이'로 상승반전…2776.64
# Label: 0
# Title: "주주가치 제고와 함께 기업경쟁력 높일 제도 개선 모색해야"(종합)
# Label: 0
# Title: ‘동해 가스전’ 동력 정점 찍었나…가스공사 오늘은 7%↓
# Label: 0
# Title: “엔비디아 다시 반등했다”···SK하이닉스·한미반도체도 ‘방긋’[특징주]
# Label: 0
# Title: KB증권, 한국여성재단에 건강차 세트 기부
# Label: 0
# Title: 교보증권, 여의샛강생태공원 환경보호 활동 실시
# Label: 0
# Title: 이복현 “코리아 디스카운트 원인은 기업지배구조 모순”
# Label: 0
# Title: 코스피, 달러 강세에 하락 출발…외국인·기관 '팔자' [오전 시황]
# Label: 0
# Title: [특징주] 지씨셀, 美관계사와 치료제 공동개발 계약 해지에 52주 신저가
# Label: 0
# Title: 눈치보는 코스피, 달러 강세에 하락 출발 뒤 강보합권(종합)
# Label: 0
# Title: 유진證, 투자 세미나 '여의도포럼' 개최…하반기 금리 전망 소개
# Label: 0
# Title: "주주가치 제고와 함께 기업경쟁력 높일 제도 개선 모색해야"
# ...

# %%
import requests
from bs4 import BeautifulSoup
from datetime import datetime, timedelta

# 뉴스 데이터를 저장할 리스트
market_conditions7 = []

# 날짜와 페이지 번호 반복
for day in range(6, 0, -1):  # 20240705부터 20240701까지
    date = f'202407{day:02d}'
    for page in range(1, 20):  # 각 날짜의 페이지 번호 1부터 4까지
        # 현재 페이지 URL 생성
        url = f'https://finance.naver.com/news/news_list.naver?mode=LSS3D&section_id=101&section_id2=258&section_id3=401&date={date}&page={page}'

        # 웹사이트에 HTTP GET 요청을 보내서 페이지 내용을 가져옴
        response = requests.get(url)

        # BeautifulSoup을 사용하여 페이지 파싱
        soup = BeautifulSoup(response.content, 'html.parser')

        # 상단 10개의 기사 추출
        top_articles = soup.select('li.newsList.top dl dd.articleSubject a')
        for title_tag in top_articles:
            title = title_tag.text.strip() if title_tag else "No title"
            news_item = {
                'title': title,
                'label': str(0)
            }
            market_conditions7.append(news_item)

        # 하단 10개의 기사 추출
        bottom_articles = soup.select('li.newsList:not(.top) dl dd.articleSubject a')
        for title_tag in bottom_articles:
            title = title_tag.text.strip() if title_tag else "No title"
            news_item = {
                'title': title,
                'label': str(0)
            }
            market_conditions7.append(news_item)

# 수집한 뉴스 데이터를 출력
for news in market_conditions7:
    print(f"Title: {news['title']}")
    print(f"Label: {news['label']}")
# Out:
# Title: 금리인하 기대감에 사상 최고치 찍은 美증시...한국은?
# Label: 0
# Title: 삼성전자가 먼저 쏜 축포…"다음엔 이 종목" 청신호 켜졌다
# Label: 0
# Title: "테슬라 반등했는데 한국은 언제쯤"…개미들 속탄다 [한경우의 케이스스터디]
# Label: 0
# Title: “돈냄새 잘맡는다며 왜 못봤지”…업계 1등 ‘이 회사’ 영업이익률 1년새 2배 쑥 [매일 ..
# Label: 0
# Title: 29만 원·35만 원?…글로벌 금융회사들의 SK하이닉스 주가 전망은
# Label: 0
# Title: [머니플로우] 박스권 갇힌 증시 대기자금…해외투자 쏠림 여전
# Label: 0
# Title: '네카오' 시총 올해 들어 15조 증발…외국인 보유율 '뚝'
# Label: 0
# Title: [ETF언박싱]고령화 대응…‘안티에이징’ 기업 액티브 투자
# Label: 0
# Title: [다음주 증시 전망] 삼전이 밀어올린 코스피…시장의 눈은 美 물가지표로
# Label: 0
# Title: 코스피, 2,860선 마감…이틀 연속 연중 최고치
# Label: 0
# Title: 깜짝 실적에 지붕 뚫더니…"목표가 12만전자" 전망 나왔다
# Label: 0
# Title: 한화그룹 경영권승계 가속화 '에너지·한화 합병설' 힘받나
# Label: 0
# Title: [ETF줌인] '밸류업' 금융지주사 투자, 상장 8일 만에 8%대 상승
# Label: 0
# Title: "로봇 산업 선두 기업" 호평에…네이버, 모처럼 '함박웃음'
# Label: 0
# Title: 삼성전자 주가 3년반 만에 최고…"엔비디아 승인땐 추가 상승"
# Label: 0
# Title: 주가 떨어지는데 설상가상…자사주 파는 카카오 임원
# Label: 0
# Title: [데이터로 보는 증시]채권 수익률 현황(7월 5일)
# Label: 0
# Title: 코스피 연이틀 52주 신고가··· KB금융은 종가기준 사상최고가
# Label: 0
# ...

# %% [markdown]
# ## 기업 종목 분석

# %%
import requests
from bs4 import BeautifulSoup

# 뉴스 데이터를 저장할 리스트
business_category = []

# 날짜와 페이지 번호 반복
for day in range(30, 0, -1):  # 20240705부터 20240701까지
    date = f'202406{day:02d}'
    for page in range(1, 20):  # 각 날짜의 페이지 번호 1부터 4까지
        # 현재 페이지 URL 생성
        url = f'https://finance.naver.com/news/news_list.naver?mode=LSS3D&section_id=101&section_id2=258&section_id3=402&date={date}&page={page}'

        # 웹사이트에 HTTP GET 요청을 보내서 페이지 내용을 가져옴
        response = requests.get(url)

        # BeautifulSoup을 사용하여 페이지 파싱
        soup = BeautifulSoup(response.content, 'html.parser')

        # 상단 10개의 기사 추출
        top_articles = soup.select('li.newsList.top dl dd.articleSubject a')
        for title_tag in top_articles:
            title = title_tag.text.strip() if title_tag else "No title"
            news_item = {
                'title': title,
                'label': str(1)
            }
            business_category.append(news_item)

        # 하단 10개의 기사 추출
        bottom_articles = soup.select('li.newsList:not(.top) dl dd.articleSubject a')
        for title_tag in bottom_articles:
            title = title_tag.text.strip() if title_tag else "No title"
            news_item = {
                'title': title,
                'label': str(1)
            }
            business_category.append(news_item)

# 수집한 뉴스 데이터를 출력
for news in business_category:
    print(f"Title: {news['title']}")
    print(f"Label: {news['label']}")
# Out:
# 스트리밍 출력 내용이 길어서 마지막 5000줄이 삭제되었습니다.
# Title: 돌아온 '강달러'…눌리는 코스피·방어 나선 코스닥
# Label: 1
# Title: CBRE코리아, 마스터리스 특화 분양형 상업시설 리테일 서비스 제공
# Label: 1
# Title: "파운드리 결함 사실 아니다"…'8만전자' 가격 테스트
# Label: 1
# Title: 엔비디아 반등에 SK하이닉스·한미반도체 덩달아 상승[특징주]
# Label: 1
# Title: “진에어 2분기 어닝쇼크 추정…목표가 1만 8000→1만 4000원”
# Label: 1
# Title: "미국 수출 추진 중"…대원전선, 전선 호황기 진입 분석에 급등
# Label: 1
# Title: "하반기 원달러 환율, 1350~1400원 등락... 약할 이유 없다"
# Label: 1
# Title: 하이로닉, 범용전기수술 의료기기 ‘실크로™' 美FDA 승인
# Label: 1
# Title: 석경에이티, 이스라엘 환경기업에 실리카 공급 "SRM 유럽 실증 확대"
# Label: 1
# Title: 롯데케미칼, 하반기 흑자전환 예상...저평가 탈출 시도-유안타증권
# Label: 1
# Title: KB증권, '한국여성재단'에 건강차 세트 기부
# Label: 1
# Title: 서현회계법인, 파트너 인사 단행···3명 중 2명 여성
# Label: 1
# Title: '거품론' 엔비디아, 줍줍에 급반등…SK하이닉스, 다시 달릴까
# Label: 1
# Title: "에스티팜, RNAi 치료제 적응증 확대 기대…목표가↑"-유안타
# Label: 1
# Title: "밀리의서재, AI 도입과 B2B 거래로 실적 개선 전망"-미래에셋
# Label: 1
# Title: "기다리던 하반기 왔다" 한화證, 코스메카코리아 목표가 9만원으로 상향
# Label: 1
# Title: “KT, 배당 매력에 자사주 소각 기대도”…목표주가 4만5천원으로 ‘쑥’
# Label: 1
# ...

# %%
import requests
from bs4 import BeautifulSoup

# 뉴스 데이터를 저장할 리스트
business_category7 = []

# 날짜와 페이지 번호 반복
for day in range(6, 0, -1):  # 20240705부터 20240701까지
    date = f'202407{day:02d}'
    for page in range(1, 20):  # 각 날짜의 페이지 번호 1부터 4까지
        # 현재 페이지 URL 생성
        url = f'https://finance.naver.com/news/news_list.naver?mode=LSS3D&section_id=101&section_id2=258&section_id3=402&date={date}&page={page}'

        # 웹사이트에 HTTP GET 요청을 보내서 페이지 내용을 가져옴
        response = requests.get(url)

        # BeautifulSoup을 사용하여 페이지 파싱
        soup = BeautifulSoup(response.content, 'html.parser')

        # 상단 10개의 기사 추출
        top_articles = soup.select('li.newsList.top dl dd.articleSubject a')
        for title_tag in top_articles:
            title = title_tag.text.strip() if title_tag else "No title"
            news_item = {
                'title': title,
                'label': str(1)
            }
            business_category7.append(news_item)

        # 하단 10개의 기사 추출
        bottom_articles = soup.select('li.newsList:not(.top) dl dd.articleSubject a')
        for title_tag in bottom_articles:
            title = title_tag.text.strip() if title_tag else "No title"
            news_item = {
                'title': title,
                'label': str(1)
            }
            business_category7.append(news_item)

# 수집한 뉴스 데이터를 출력
for news in business_category7:
    print(f"Title: {news['title']}")
    print(f"Label: {news['label']}")
# Out:
# Title: 삼성 실적 대박 나더니 왜 또…"이틀 만에 3조원" 난리 났다 [노정동의 어쩌다 투자자]
# Label: 1
# Title: 삼성전자가 먼저 쏜 축포…"다음엔 이 종목" 청신호 켜졌다
# Label: 1
# Title: 네카오 시총 올해 들어 '15조' 날아갔다...외국인 보유율 급감
# Label: 1
# Title: "주식 잘 팔아 집 샀다"는 아이돌…"또 신저가" 상투 잡은 개미는 한숨
# Label: 1
# Title: 7월 첫째 주, 마켓PRO 핫종목·주요 이슈 5분 완벽정리 [위클리 리뷰]
# Label: 1
# Title: 크래프톤은 40% 떨어졌는데… '공모 흥행' 시프트업은 다를까?
# Label: 1
# Title: 시총 15조원 증발…'네카오' 외국인 팔았다
# Label: 1
# Title: "안유진 광고 나올 때 사둘 걸"…개미들 '탄식' 쏟아낸 이유 [윤현주의 主食이 주식]
# Label: 1
# Title: 52주 신고가 찍은 삼성전자... 3분기 실적 성장 이어간다
# Label: 1
# Title: 메타 13%↑, 아마존 9%↑…기술주 추가 상승 점치는 美 차트 분석가 [양병훈의 해외주식..
# Label: 1
# Title: 정부 야심차게 발표한 '밸류업', 현실성 있나..."기대 낮춰야"
# Label: 1
# Title: 바이 코리아는 옛말..펀드도 해외주식
# Label: 1
# Title: 삼성전자, 목표주가 10.6만→11.7만..저평가 이유 없어-하나
# Label: 1
# Title: “서러웠던 삼전 개미, 눈물의 환호”…주가 3% 올라 올들어 최고치
# Label: 1
# Title: “테슬람의 기도를 들어주셨군요”…주가 부활하자 ETF 수익률도 1위
# Label: 1
# Title: 주가 30% 떨어졌는데 "아직 비싸"…증권가 경고한 종목
# Label: 1
# Title: 달리는 로봇株…에브리봇·이랜시스 '쑥'
# Label: 1
# ...

# %%
len(business_category)
# Out:
# 343

# %% [markdown]
# 해외 증시

# %%
import requests
from bs4 import BeautifulSoup

# 뉴스 데이터를 저장할 리스트
global_market = []

# 날짜와 페이지 번호 반복
for day in range(30, 0, -1):  # 20240705부터 20240701까지
    date = f'202406{day:02d}'
    for page in range(1, 20):  # 각 날짜의 페이지 번호 1부터 4까지
        # 현재 페이지 URL 생성
        url = f'https://finance.naver.com/news/news_list.naver?mode=LSS3D&section_id=101&section_id2=258&section_id3=403&date={date}&page={page}'

        # 웹사이트에 HTTP GET 요청을 보내서 페이지 내용을 가져옴
        response = requests.get(url)

        # BeautifulSoup을 사용하여 페이지 파싱
        soup = BeautifulSoup(response.content, 'html.parser')

        # 상단 10개의 기사 추출
        top_articles = soup.select('li.newsList.top dl dd.articleSubject a')
        for title_tag in top_articles:
            title = title_tag.text.strip() if title_tag else "No title"
            news_item = {
                'title': title,
                'label': str(2)
            }
            global_market.append(news_item)

        # 하단 10개의 기사 추출
        bottom_articles = soup.select('li.newsList:not(.top) dl dd.articleSubject a')
        for title_tag in bottom_articles:
            title = title_tag.text.strip() if title_tag else "No title"
            news_item = {
                'title': title,
                'label': str(2)
            }
            global_market.append(news_item)

# 수집한 뉴스 데이터를 출력
for news in global_market:
    print(f"Title: {news['title']}")
    print(f"Label: {news['label']}")
# Out:
# Title: "이젠 떠날 시간"…토론 참패 바이든, 후보 교체론 후폭풍
# Label: 2
# Title: 뜨거운 비만약 테마주…후발주자에 관심
# Label: 2
# Title: 정치적 불확실성 극복한 인도·극우 득세 우려되는 유럽···정치 이벤트에 해외펀드 수익률 갈..
# Label: 2
# Title: 개미들 “국장 탈출은 지능순” 외칠때…22조 쓸어담은 외국인
# Label: 2
# Title: 코스피 2800 넘나 … 삼전 실적발표 주목
# Label: 2
# Title: 2800 목전 코스피, 삼전 실적 발표 관심
# Label: 2
# Title: S&P500 상반기 14% '껑충'…초대형주 편중
# Label: 2
# Title: 도요타 자회사도 하청업체에 '갑질'…공짜로 장비 보관 위탁
# Label: 2
# Title: 미 S&P500 상반기 14% 상승…엔비디아 등 5개 초대형주 주도
# %%
import requests
from bs4 import BeautifulSoup

# 뉴스 데이터를 저장할 리스트
bond_future = []

# 날짜와 페이지 번호 반복
for day in range(30, 0, -1):  # 20240705부터 20240701까지
    date = f'202406{day:02d}'
    for page in range(1, 20):  # 각 날짜의 페이지 번호 1부터 4까지
        # 현재 페이지 URL 생성
        url = f'https://finance.naver.com/news/news_list.naver?mode=LSS3D&section_id=101&section_id2=258&section_id3=404&date={date}&page={page}'

        # 웹사이트에 HTTP GET 요청을 보내서 페이지 내용을 가져옴
        response = requests.get(url)

        # BeautifulSoup을 사용하여 페이지 파싱
        soup = BeautifulSoup(response.content, 'html.parser')

        # 상단 10개의 기사 추출
        top_articles = soup.select('li.newsList.top dl dd.articleSubject a')
        for title_tag in top_articles:
            title = title_tag.text.strip() if title_tag else "No title"
            news_item = {
                'title': title,
                'label': str(3)
            }
            bond_future.append(news_item)

        # 하단 10개의 기사 추출
        bottom_articles = soup.select('li.newsList:not(.top) dl dd.articleSubject a')
        for title_tag in bottom_articles:
            title = title_tag.text.strip() if title_tag else "No title"
            news_item = {
                'title': title,
                'label': str(3)
            }
            bond_future.append(news_item)

# 수집한 뉴스 데이터를 출력
for news in bond_future:
    print(f"Title: {news['title']}")
    print(f"Label: {news['label']}")
# Out:
# Title: AA급 건설채 ‘DL이앤씨’…3년만 공모채 시장 복귀
# Label: 3
# Title: 3.1%대 진입한 3년물…미 6월 고용지표와 파월·라가르드 연설 주시[주간채권전망]
# Label: 3
# Title: 저축은행 신용도 '우수수'…올해 16곳 등급·전망 하향 조정
# Label: 3
# Title: 저축은행, 개인사업자 부실채권 매각 확대…3차 PF 펀드도 조성
# Label: 3
# Title: [위클리 크레딧]롯데그룹 등급 전망 '부정적' 하향
# Label: 3
# Title: 채권 투자자, 23조원 넘게 순매수 '역대 최대'
# Label: 3
# Title: 비트코인 6만 달러도 위태…美인플레이션 둔화에도 하락세
# Label: 3
# Title: [머니플로우] 채권 개미, 올 상반기 23조6천억 순매수 '역대 최대'
# Label: 3
# Title: 국고채 금리, 내수 부진에 일제히 하락…3년물 3.182%(종합)
# Label: 3
# Title: 저가매수에 3bp 내외 하락…미국 5월 PCE 발표 대기[채권마감]
# Label: 3
# Title: 국채통합계좌 시스템 오픈 기념식
# Label: 3
# Title: 정부, 흥행 '10년물 개인국채' 1500억 발행
# Label: 3
# Title: 정부, '개인투자용 국채' 20년물 줄여 10년물 더 발행한다
# Label: 3
# Title: 예탁원, 국채통합계좌 개통 기념식 개최…"外人 투자 접근성 ↑"
# Label: 3
# Title: 공무원연금공단, 연금담당자 CS옴부즈맨 발대식 개최
# Label: 3
# Title: 미국채 10년물 4.3% 돌파에도 1bp 미만 하락…미 5월 PCE 대기[채권분석]
# Label: 3
# Title: [위클리 크레딧]롯데그룹 등급 전망 '부정적' 하향
# Label: 3
# Title: 채권 투자자, 23조원 넘게 순매수 '역대 최대'
# Label: 3
# Title: 비트코인 6만 달러도 위태…美인플레이션 둔화에도 하락세
# ...

# %%
import requests
from bs4 import BeautifulSoup

# 뉴스 데이터를 저장할 리스트
bond_future7 = []

# 날짜와 페이지 번호 반복
for day in range(6, 0, -1):  # 20240705부터 20240701까지
    date = f'202407{day:02d}'
    for page in range(1, 20):  # 각 날짜의 페이지 번호 1부터 4까지
        # 현재 페이지 URL 생성
        url = f'https://finance.naver.com/news/news_list.naver?mode=LSS3D&section_id=101&section_id2=258&section_id3=404&date={date}&page={page}'

        # 웹사이트에 HTTP GET 요청을 보내서 페이지 내용을 가져옴
        response = requests.get(url)

        # BeautifulSoup을 사용하여 페이지 파싱
        soup = BeautifulSoup(response.content, 'html.parser')

        # 상단 10개의 기사 추출
        top_articles = soup.select('li.newsList.top dl dd.articleSubject a')
        for title_tag in top_articles:
            title = title_tag.text.strip() if title_tag else "No title"
            news_item = {
                'title': title,
                'label': str(3)
            }
            bond_future7.append(news_item)

        # 하단 10개의 기사 추출
        bottom_articles = soup.select('li.newsList:not(.top) dl dd.articleSubject a')
        for title_tag in bottom_articles:
            title = title_tag.text.strip() if title_tag else "No title"
            news_item = {
                'title': title,
                'label': str(3)
            }
            bond_future7.append(news_item)

# 수집한 뉴스 데이터를 출력
for news in bond_future7:
    print(f"Title: {news['title']}")
    print(f"Label: {news['label']}")
# Out:
# Title: 환율 언제 꺾이나…달러 하락에 베팅한 개미들 "속타네"
# Label: 3
# Title: 국고채 금리, 금통위 대기 속 대체로 하락…3년물 3.115%(종합)
# Label: 3
# Title: 사흘째 연저점 경신한 3년물 금리…미국 6월 고용보고서 대기[채권마감]
# Label: 3
# Title: 미 6월 고용지표 앞두고 숨 고르기…3년물 금리, 0.7bp 상승[채권분석]
# Label: 3
# Title: 공무원연금·사학연금, 디지털플랫폼정부 위해 ‘맞손’
# Label: 3
# Title: 반등 요원한 건설·증권·화학…하반기도 힘들다
# Label: 3
# Title: 국고채 금리, 1bp 미만 등락하며 보합 출발…3년물, 0.3bp↑
# Label: 3

# ...

# %%
import requests
from bs4 import BeautifulSoup

# 뉴스 데이터를 저장할 리스트
official_notice7 = []

# 날짜와 페이지 번호 반복
for day in range(6, 0, -1):  # 20240705부터 20240701까지
    date = f'202407{day:02d}'
    for page in range(1, 20):  # 각 날짜의 페이지 번호 1부터 4까지
        # 현재 페이지 URL 생성
        url = f'https://finance.naver.com/news/news_list.naver?mode=LSS3D&section_id=101&section_id2=258&section_id3=406&date={date}&page={page}'

        # 웹사이트에 HTTP GET 요청을 보내서 페이지 내용을 가져옴
        response = requests.get(url)

        # BeautifulSoup을 사용하여 페이지 파싱
        soup = BeautifulSoup(response.content, 'html.parser')

        # 상단 10개의 기사 추출
        top_articles = soup.select('li.newsList.top dl dd.articleSubject a')
        for title_tag in top_articles:
            title = title_tag.text.strip() if title_tag else "No title"
            news_item = {
                'title': title,
                'label': str(4)
            }
            official_notice7.append(news_item)

        # 하단 10개의 기사 추출
        bottom_articles = soup.select('li.newsList:not(.top) dl dd.articleSubject a')
        for title_tag in bottom_articles:
            title = title_tag.text.strip() if title_tag else "No title"
            news_item = {
                'title': title,
                'label': str(4)
            }
            official_notice7.append(news_item)

# 수집한 뉴스 데이터를 출력
for news in official_notice7:
    print(f"Title: {news['title']}")
    print(f"Label: {news['label']}")
# Out:
# Title: 세운5구역 재개발사업 재개되나…GS건설, 태영건설 지분 인수
# Label: 4
# Title: 정지선 회장, 현대그린푸드 지분 전량 가족 증여…514억원 상당
# Label: 4
# Title: 크래프톤 "카카오게임즈 인수설은 사실무근" [주목 e공시]
# Label: 4
# Title: 한화, 오너 일가 공개매수에 주가 4% 넘게 상승(종합)
# Label: 4
# Title: 동방, 쿠팡과 694억 규모 간선 운송 위탁 계약 [주목 e공시]
# Label: 4
# Title: 세운5구역 재개발사업 재개되나…GS건설, 태영건설 지분 인수
# Label: 4
# Title: 정지선 회장, 현대그린푸드 지분 전량 가족 증여…514억원 상당
# Label: 4
# Title: 크래프톤 "카카오게임즈 인수설은 사실무근" [주목 e공시]
# Label: 4
# Title: 한화, 오너 일가 공개매수에 주가 4% 넘게 상승(종합)
# Label: 4
# Title: 동방, 쿠팡과 694억 규모 간선 운송 위탁 계약 [주목 e공시]
# Label: 4
# Title: 가전 끌고 B2B 밀고…LG전자, 2분기 역대 최대 실적 썼다(종합)
# Label: 4
# Title: 케어젠, 주당 240원 중간배당 결정 [주목 e공시]
# Label: 4
# Title: [그래픽] LG전자 실적 추이
# Label: 4
# Title: [2보] LG전자, 영업익 1.2조로 역대 2분기 최대…가전·B2B '쌍끌이'
# Label: 4
# Title: [1보] LG전자 2분기 영업이익 1조1천961억원…작년 동기 대비 61.2%↑
# Label: 4
# Title: 신제품 효과 떨어진 삼성 모바일, 2분기 실적 둔화했을 듯
# Label: 4
# Title: [특징주] 한화, 오너 일가 공개매수에 4% 넘게 상승
# Label: 4
# Title: "다시 메모리의 시간"…삼성전자 2분기 영업익 10.4조 '깜짝실적'(종합)
# Label: 4
# ...

# %%
len(official_notice)
# Out:
# 45

# %% [markdown]
# 환율

# %%
import requests
from bs4 import BeautifulSoup

# 뉴스 데이터를 저장할 리스트
exchange_rate = []

# 날짜와 페이지 번호 반복
for day in range(30, 0, -1):  # 20240705부터 20240701까지
    date = f'202406{day:02d}'
    for page in range(1, 20):  # 각 날짜의 페이지 번호 1부터 4까지
        # 현재 페이지 URL 생성
        url = f'https://finance.naver.com/news/news_list.naver?mode=LSS3D&section_id=101&section_id2=258&section_id3=429&date={date}&page={page}'

        # 웹사이트에 HTTP GET 요청을 보내서 페이지 내용을 가져옴
        response = requests.get(url)

        # BeautifulSoup을 사용하여 페이지 파싱
        soup = BeautifulSoup(response.content, 'html.parser')

        # 상단 10개의 기사 추출
        top_articles = soup.select('li.newsList.top dl dd.articleSubject a')
        for title_tag in top_articles:
            title = title_tag.text.strip() if title_tag else "No title"
            news_item = {
                'title': title,
                'label': str(5)
            }
            exchange_rate.append(news_item)

        # 하단 10개의 기사 추출
        bottom_articles = soup.select('li.newsList:not(.top) dl dd.articleSubject a')
        for title_tag in bottom_articles:
            title = title_tag.text.strip() if title_tag else "No title"
            news_item = {
                'title': title,
                'label': str(5)
            }
            exchange_rate.append(news_item)

# 수집한 뉴스 데이터를 출력
for news in exchange_rate:
    print(f"Title: {news['title']}")
    print(f"Label: {news['label']}")
# Out:
# Title: 외환시장 거래 새벽 2시로 연장…간이과세 금액 상향
# Label: 5
# Title: '슈퍼 엔저'에…5대 은행 엔화 예금 올해에만 1.4조원 불었다
# Label: 5
# Title: 외환당국, 1분기 '환율 방어'에 18억달러 팔았다
# Label: 5
# Title: 원/달러 환율, 달러 매도세에 9.1원 하락…1,376.7원
# Label: 5
# Title: 엔화값 너무 떨어져서…외국인 일본 증시서 5주 연속 순매도
# Label: 5
# Title: 원/달러 환율, 장 초반 소폭 하락…1,384.7원
# Label: 5
# Title: 엔화가치 38년來 최저…"美 금리인하 멀어지면 170엔 갈수도"
# Label: 5
# Title: [경제쏙쏙] '최강 달러'에 환율 불안…또 '슈퍼 엔저'
# Label: 5
# Title: 환율, 1,390원선 넘었다가 하락 전환…1,385.8원으로 마감
# Label: 5
# Title: 日재무상, 37년여만의 엔/달러 161엔 근접에 "필요시 적절 대응"
# Label: 5
# Title: 엔화 추락…달러 대비 아시아 통화 가치도 1년7개월 만에 최저
# Label: 5
# Title: 원/달러 환율, 달러 강세·엔화 약세에 상승…1,392.2원
# Label: 5
# Title: 한은, 환율 고공행진에 "2022년보다는 변동성 작아"
# Label: 5
# Title: 美연준 '매파' 발언에 엔/달러 환율 160.39엔…37년만에 최고(종합)
# Label: 5
# Title: 원·달러 환율 소폭 상승…한은 "2022년보다 양호한 상황" [한경 외환시장 워치]
# Label: 5
# Title: 환율, 美 금리인하 기대 후퇴에 소폭 상승…1,388.7원
# Label: 5
# Title: [김대호의 경제읽기] 원·달러 환율 고공행진…1,400원대 돌파하나?
# Label: 5
# Title: 환율, 美 금리인하 기대 후퇴에 상승…1,391.9원
# Label: 5
# ...

# %%
import requests
from bs4 import BeautifulSoup

# 뉴스 데이터를 저장할 리스트
exchange_rate7 = []

# 날짜와 페이지 번호 반복
for day in range(6, 0, -1):  # 20240705부터 20240701까지
    date = f'202407{day:02d}'
    for page in range(1, 20):  # 각 날짜의 페이지 번호 1부터 4까지
        # 현재 페이지 URL 생성
        url = f'https://finance.naver.com/news/news_list.naver?mode=LSS3D&section_id=101&section_id2=258&section_id3=429&date={date}&page={page}'

        # 웹사이트에 HTTP GET 요청을 보내서 페이지 내용을 가져옴
        response = requests.get(url)

        # BeautifulSoup을 사용하여 페이지 파싱
        soup = BeautifulSoup(response.content, 'html.parser')

        # 상단 10개의 기사 추출
        top_articles = soup.select('li.newsList.top dl dd.articleSubject a')
        for title_tag in top_articles:
            title = title_tag.text.strip() if title_tag else "No title"
            news_item = {
                'title': title,
                'label': str(5)
            }
            exchange_rate7.append(news_item)

        # 하단 10개의 기사 추출
        bottom_articles = soup.select('li.newsList:not(.top) dl dd.articleSubject a')
        for title_tag in bottom_articles:
            title = title_tag.text.strip() if title_tag else "No title"
            news_item = {
                'title': title,
                'label': str(5)
            }
            exchange_rate7.append(news_item)

# 수집한 뉴스 데이터를 출력
for news in exchange_rate7:
    print(f"Title: {news['title']}")
    print(f"Label: {news['label']}")
# Out:
# Title: 원/달러 환율, 0.1원 하락…1,380.3원
# Label: 5
# Title: [외환] 원/달러 환율 0.1원 내린 1,380.3원(마감)
# Label: 5
# Title: 英 총선 노동당 압승 전망…유럽 주식 상승·파운드화 안정
# Label: 5
# Title: 원/달러 환율, 장 초반 소폭 하락…1,377.7원
# Label: 5
# Title: [외환] 원/달러 환율 0.9원 내린 1,380.1원(개장)
# Label: 5
# Title: 원/달러 환율, 10.2원 하락…1,380.4원
# Label: 5
# Title: 원/달러 환율, 장 초반 하락…1,380원대 중반
# Label: 5
# Title: 미 금리인하 기대에 아시아 증시도 강세…엔·원화 더 하락
# Label: 5
# Title: '달러당 1400원' 방어에…상반기 79억 달러 썼다
# Label: 5
# Title: 원/달러 환율, 2.4원 상승…1,390.6원
# Label: 5
# Title: 외환보유액 감소
# Label: 5
# Title: 외환보유액 감소
# Label: 5
# Title: 외환보유액 감소
# Label: 5
# Title: 외환보유액 석달 연속 감소
# Label: 5
# Title: 외환보유액 석달 연속 감소
# Label: 5
# Title: 외환보유액 석달 연속 감소
# Label: 5
# Title: 외환보유액 줄었다
# Label: 5
# Title: 외환보유액 줄었다
# Label: 5
# Title: 외환보유액 줄었다
# Label: 5
# Title: 외환보유액 석달 연속 감소
# Label: 5
# Title: 원/달러 환율, 0.1원 하락…1,380.3원
# Label: 5
# Title: [외환] 원/달러 환율 0.1원 내린 1,380.3원(마감)
# Label: 5
# Title: 英 총선 노동당 압승 전망…유럽 주식 상승·파운드화 안정
# Label: 5
# ...

# %%
len(exchange_rate)
# Out:
# 100

# %% [markdown]
# 데이터 합치기

# %%
# 여러 리스트를 하나의 리스트로 합침
import itertools

combined_list = list(itertools.chain(market_conditions, business_category, global_market, bond_future, official_notice, exchange_rate, market_conditions7, business_category7, global_market7, bond_future7, official_notice7, exchange_rate7))

len(combined_list)
# Out:
# 10552

# %%
combined_list[0:30]
# Out:
# [{'title': '"대체거래소 도입은 시대적 요구…퇴근시간 주식거래 현실된다"', 'label': '0'},
#  {'title': '23조 사들인 외국인, 상위 10종목 주가 평균 71% 올랐다 [증시 상반기 결산]', 'label': '0'},
#  {'title': '상반기 새내기株 셋 중 둘은 공모가 하회…아이씨티케이 반토막', 'label': '0'},
#  {'title': '금투협, 규제샌드박스 신청…자산운용사 30곳 공모펀드 직상장 준비', 'label': '0'},
#  {'title': '"韓증시 中보다 투명성 떨어져"…쓴소리 쏟아낸 해외투자자', 'label': '0'},
#  {'title': "'3.5조 대어' 시프트업, 7월2일 일반 청약", 'label': '0'},
#  {'title': "'투자 일타강사' 총출동…돈 버는 꿀팁 대방출 [서울경제 머니트렌드 2024]", 'label': '0'},
#  {'title': '2분기 어닝시즌 개막…파인엠텍 등 실적株 주목을 [이번주 추천주]', 'label': '0'},
#  {'title': "OCI홀딩스, '친환경 폴리실리콘' 강자…美서도 러브콜", 'label': '0'},
#  {'title': '거래대금 늘어난 코스피…코스닥은 찬바람 쌩쌩', 'label': '0'},
#  {'title': '외국인 韓주식 23조 살때 … 개미는 해외로', 'label': '0'},
#  {'title': '“빛의 속도로 오를 줄 알았더니”...치솟던 ‘이 종목’ 숨고르기', 'label': '0'},
#  {'title': '개미들 “국장 탈출은 지능순” 외칠때…22조 쓸어담은 외국인', 'label': '0'},
#  {'title': '“조단위는 우습지”...덩치 큰 새내기들, 하반기에 줄줄이 뛰어든다', 'label': '0'},
#  {'title': "너무 올랐나…AI 전력株 '숨고르기'", 'label': '0'},
# ...

# %%
import pandas as pd
df = pd.DataFrame(combined_list)

# Save the DataFrame to a CSV file
csv_file_path = "/content/drive/MyDrive/딥러닝/news.csv"
df.to_csv(csv_file_path, index=False)

csv_file_path
# Out:
# '/content/drive/MyDrive/딥러닝/news.csv'
